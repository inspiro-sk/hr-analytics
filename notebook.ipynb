# %% [markdown]
# ## Import libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Read dataset into dataframe

# %%
df = pd.read_csv('inputs/general_data.csv')
df.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %% [markdown]
# ## Cleanup dataframe

# %%
def nan_columns(dataframe):
    return list(df.columns.values[df.isna().sum() > 0])

# %%
print(nan_columns(df))
# Out:
# ['NumCompaniesWorked', 'TotalWorkingYears']

# %%
import psycopg2

# Establish a connection to the database by creating a cursor object
conn = psycopg2.connect(host="localhost", port = 5432, database="feast_demo", user="rstana", password="23Mud2h5@")

# A sample query of all data from the "vendors" table in the "suppliers" database
df1 = pd.read_sql('SELECT * FROM general_data', conn)
df1.head()
# Out:
#    id  age attrition     businesstravel              department  \
# 0   1   51        No      Travel_Rarely                   Sales
# 1   2   51        No      Travel_Rarely                   Sales
# 2   3   31       Yes  Travel_Frequently  Research & Development
# 3   4   32        No  Travel_Frequently  Research & Development
# 4   5   38        No         Non-Travel  Research & Development
#
#    distancefromhome  education educationfield  employeecount  employeeid  ...  \
# 0                 6          2  Life Sciences              1           1  ...
# 1                 6          2  Life Sciences              1           1  ...
# 2                10          1  Life Sciences              1           2  ...
# 3                17          4          Other              1           3  ...
# 4                 2          5  Life Sciences              1           4  ...
#
#   numcompaniesworked  over18 percentsalaryhike standardhours  \
# ...
